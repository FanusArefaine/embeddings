# %%
import os 
import sys

sys.path.append('..')

# %%
from src.config import Config
from src.evaluation_pipeline import run_evaluation

# %%
cfg = Config()


run_evaluation(cfg)
# Out:
# Test split not found. Generating splits now...
# No existing splits found. Creating new splits from PubMedQA...
# Saved new train/val/test splits to disk.
# Test size: 2000
# Extracting context docs and questions...
# Cached context docs -> /teamspace/studios/this_studio/embeddings/data/processed/test_contexts.pkl
# Cached question entries -> /teamspace/studios/this_studio/embeddings/data/processed/test_questions.pkl
# Number of questions: 2000
# Number of context docs: 6000
# FAISS index size: 6000
#
# === Evaluation Results ===
# Metric              Value
# -------------------------
# Precision@k          0.8063
# Recall@k             0.8063
# F1@k                 0.8063
# AveragePrecision     0.7977
# MRR                  0.9922
# R-Precision          0.8063
# nDCG@k               0.9894
